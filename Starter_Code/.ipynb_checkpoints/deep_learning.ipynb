# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 

application_df = pd.read_csv("../content/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.drop(columns=["EIN","NAME"])
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1              0                      N      5000
# 1      Co-operative       1         1-9999                      N    108590
# 2       Association       1              0                      N      5000
# 3             Trust       1    10000-24999                      N      6692
# 4             Trust       1  100000-499999                      N    142590
# ...             ...     ...            ...                    ...       ...
# 34294   Association       1              0                      N      5000
# 34295   Association       1              0                      N      5000
# 34296   Association       1              0                      N      5000
# 34297   Association       1              0                      N      5000
# 34298  Co-operative       1          1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 10 columns]

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# EIN                       34299
# NAME                      19568
# APPLICATION_TYPE             17
# AFFILIATION                   6
# CLASSIFICATION               71
# USE_CASE                      5
# ORGANIZATION                  4
# STATUS                        2
# INCOME_AMT                    9
# SPECIAL_CONSIDERATIONS        2
# ASK_AMT                    8747
# IS_SUCCESSFUL                 2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df["APPLICATION_TYPE"].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = ["T7","T10","T13","T17","T25","T19"]

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# Other     2388
# T4        1542
# T6        1216
# T5        1173
# T8         737
# T9         156
# T12         27
# T2          16
# T14          3
# T29          2
# T15          2
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df["CLASSIFICATION"].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
application_df["CLASSIFICATION"].value_counts().loc[lambda x: x>1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = application_df["CLASSIFICATION"].value_counts().loc[lambda x: x==1].index

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# Other       26
# C8000       20
# C7120       18
# C1500       16
# C6000       15
# C1800       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1237        9
# C1235        9
# C7210        7
# C1720        6
# C2400        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C1267        2
# C1256        2
# C1234        2
# C1246        2
# C3200        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
X = pd.get_dummies(application_df)

# %%
# Split our preprocessed data into our features and target arrays
y = application_df['STATUS']
X = X.drop(columns='STATUS')
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 9
hidden_nodes_layer2 = 18

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=9,input_dim=number_input_features, activation="relu"))


# Second hidden layer
nn.add(tf.keras.layers.Dense(units=18, activation="relu"))
# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 9)                 176904
#
#  dense_1 (Dense)             (None, 18)                180
#
#  dense_2 (Dense)             (None, 1)                 19
#
# =================================================================
# Total params: 177,103
# Trainable params: 177,103
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 9s 9ms/step - loss: 0.1234 - accuracy: 0.9442
# Epoch 2/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.0058 - accuracy: 0.9998
# Epoch 3/100
# 804/804 [==============================] - 15s 19ms/step - loss: 0.0029 - accuracy: 0.9998
# Epoch 4/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.0020 - accuracy: 0.9998
# Epoch 5/100
# 804/804 [==============================] - 8s 9ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 6/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.0020 - accuracy: 0.9998
# Epoch 7/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0015 - accuracy: 0.9998
# Epoch 8/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.0015 - accuracy: 0.9998
# Epoch 9/100
# 804/804 [==============================] - 8s 9ms/step - loss: 0.0013 - accuracy: 0.9998
# Epoch 10/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.0013 - accuracy: 0.9998
# Epoch 11/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.0013 - accuracy: 0.9998
# Epoch 12/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0012 - accuracy: 0.9998
# Epoch 13/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.0015 - accuracy: 0.9998
# Epoch 14/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0014 - accuracy: 0.9998
# Epoch 15/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.0012 - accuracy: 0.9998
# Epoch 16/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0012 - accuracy: 0.9998
# Epoch 17/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.0014 - accuracy: 0.9998
# Epoch 18/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0012 - accuracy: 0.9998
# Epoch 19/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.0014 - accuracy: 0.9998
# Epoch 20/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.0012 - accuracy: 0.9998
# Epoch 21/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0013 - accuracy: 0.9998
# Epoch 22/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.0012 - accuracy: 0.9998
# Epoch 23/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0012 - accuracy: 0.9998
# Epoch 24/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.0012 - accuracy: 0.9998
# Epoch 25/100
# 804/804 [==============================] - 8s 9ms/step - loss: 0.0012 - accuracy: 0.9998
# Epoch 26/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.0012 - accuracy: 0.9998
# Epoch 27/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0014 - accuracy: 0.9998
# Epoch 28/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.0014 - accuracy: 0.9998
# Epoch 29/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.0011 - accuracy: 0.9998
# Epoch 30/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0010 - accuracy: 0.9998
# Epoch 31/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.0010 - accuracy: 0.9998
# Epoch 32/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0010 - accuracy: 0.9998
# Epoch 33/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.0013 - accuracy: 0.9998
# Epoch 34/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0010 - accuracy: 0.9998
# Epoch 35/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.0011 - accuracy: 0.9998
# Epoch 36/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.0010 - accuracy: 0.9998
# Epoch 37/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0010 - accuracy: 0.9998
# Epoch 38/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.0011 - accuracy: 0.9998
# Epoch 39/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0010 - accuracy: 0.9998
# Epoch 40/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.0012 - accuracy: 0.9998
# Epoch 41/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0012 - accuracy: 0.9998
# Epoch 42/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.0010 - accuracy: 0.9998
# Epoch 43/100
# 804/804 [==============================] - 8s 10ms/step - loss: 9.8468e-04 - accuracy: 0.9998
# Epoch 44/100
# 804/804 [==============================] - 7s 9ms/step - loss: 9.9951e-04 - accuracy: 0.9998
# Epoch 45/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.0013 - accuracy: 0.9998
# Epoch 46/100
# 804/804 [==============================] - 8s 9ms/step - loss: 0.0010 - accuracy: 0.9998
# Epoch 47/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.0010 - accuracy: 0.9998
# Epoch 48/100
# 804/804 [==============================] - 8s 10ms/step - loss: 9.9973e-04 - accuracy: 0.9998
# Epoch 49/100
# 804/804 [==============================] - 7s 8ms/step - loss: 9.9761e-04 - accuracy: 0.9998
# Epoch 50/100
# 804/804 [==============================] - 8s 10ms/step - loss: 9.9042e-04 - accuracy: 0.9998
# Epoch 51/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.0011 - accuracy: 0.9998
# Epoch 52/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0011 - accuracy: 0.9998
# Epoch 53/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.0011 - accuracy: 0.9998
# Epoch 54/100
# 804/804 [==============================] - 8s 9ms/step - loss: 9.8396e-04 - accuracy: 0.9998
# Epoch 55/100
# 804/804 [==============================] - 8s 9ms/step - loss: 0.0011 - accuracy: 0.9998
# Epoch 56/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.0011 - accuracy: 0.9998
# Epoch 57/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0011 - accuracy: 0.9998
# Epoch 58/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.0013 - accuracy: 0.9998
# Epoch 59/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0011 - accuracy: 0.9998
# Epoch 60/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.0011 - accuracy: 0.9998
# Epoch 61/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0011 - accuracy: 0.9998
# Epoch 62/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.0010 - accuracy: 0.9998
# Epoch 63/100
# 804/804 [==============================] - 8s 9ms/step - loss: 9.9787e-04 - accuracy: 0.9998
# Epoch 64/100
# 804/804 [==============================] - 8s 9ms/step - loss: 9.8538e-04 - accuracy: 0.9998
# Epoch 65/100
# 804/804 [==============================] - 7s 9ms/step - loss: 9.4612e-04 - accuracy: 0.9998
# Epoch 66/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0010 - accuracy: 0.9998
# Epoch 67/100
# 804/804 [==============================] - 7s 9ms/step - loss: 9.7381e-04 - accuracy: 0.9998
# Epoch 68/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0010 - accuracy: 0.9998
# Epoch 69/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.0011 - accuracy: 0.9998
# Epoch 70/100
# 804/804 [==============================] - 8s 10ms/step - loss: 9.9324e-04 - accuracy: 0.9998
# Epoch 71/100
# 804/804 [==============================] - 7s 9ms/step - loss: 9.9048e-04 - accuracy: 0.9998
# Epoch 72/100
# 804/804 [==============================] - 7s 9ms/step - loss: 9.8683e-04 - accuracy: 0.9998
# Epoch 73/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0011 - accuracy: 0.9998
# Epoch 74/100
# 804/804 [==============================] - 7s 8ms/step - loss: 9.7280e-04 - accuracy: 0.9998
# Epoch 75/100
# 804/804 [==============================] - 8s 10ms/step - loss: 9.9049e-04 - accuracy: 0.9998
# Epoch 76/100
# 804/804 [==============================] - 7s 9ms/step - loss: 9.8407e-04 - accuracy: 0.9998
# Epoch 77/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0011 - accuracy: 0.9998
# Epoch 78/100
# 804/804 [==============================] - 7s 8ms/step - loss: 9.8590e-04 - accuracy: 0.9998
# Epoch 79/100
# 804/804 [==============================] - 8s 10ms/step - loss: 9.8416e-04 - accuracy: 0.9998
# Epoch 80/100
# 804/804 [==============================] - 7s 9ms/step - loss: 9.7835e-04 - accuracy: 0.9998
# Epoch 81/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.0011 - accuracy: 0.9998
# Epoch 82/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0012 - accuracy: 0.9998
# Epoch 83/100
# 804/804 [==============================] - 7s 8ms/step - loss: 9.9675e-04 - accuracy: 0.9998
# Epoch 84/100
# 804/804 [==============================] - 8s 10ms/step - loss: 9.6548e-04 - accuracy: 0.9998
# Epoch 85/100
# 804/804 [==============================] - 7s 8ms/step - loss: 9.9619e-04 - accuracy: 0.9998
# Epoch 86/100
# 804/804 [==============================] - 8s 10ms/step - loss: 9.6757e-04 - accuracy: 0.9998
# Epoch 87/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.0010 - accuracy: 0.9998
# Epoch 88/100
# 804/804 [==============================] - 8s 9ms/step - loss: 0.0011 - accuracy: 0.9998
# Epoch 89/100
# 804/804 [==============================] - 8s 9ms/step - loss: 0.0011 - accuracy: 0.9998
# Epoch 90/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.0011 - accuracy: 0.9998
# Epoch 91/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0011 - accuracy: 0.9998
# Epoch 92/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.0011 - accuracy: 0.9998
# Epoch 93/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0011 - accuracy: 0.9998
# Epoch 94/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.0011 - accuracy: 0.9998
# Epoch 95/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0022 - accuracy: 0.9998
# Epoch 96/100
# 804/804 [==============================] - 7s 9ms/step - loss: 9.9511e-04 - accuracy: 0.9998
# Epoch 97/100
# 804/804 [==============================] - 8s 9ms/step - loss: 0.0010 - accuracy: 0.9998
# Epoch 98/100
# 804/804 [==============================] - 8s 10ms/step - loss: 9.4073e-04 - accuracy: 0.9998
# Epoch 99/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.0010 - accuracy: 0.9998
# Epoch 100/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.0011 - accuracy: 0.9998

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.0036 - accuracy: 1.0000 - 897ms/epoch - 3ms/step
# Loss: 0.003607813734561205, Accuracy: 1.0

# %%
# Export our model to HDF5 file
nn.save('AlphabetSoupCharity.h5')
